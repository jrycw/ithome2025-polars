# %%
from typing import Any

import polars as pl
from great_tables import GT, loc, style


@pl.api.register_expr_namespace("spt")
class DiscreteSplitter:
    def __init__(self, expr: pl.Expr) -> None:
        self._expr = expr

    def _mod_expr(self, n: int) -> pl.Expr:
        return pl.int_range(pl.len(), dtype=pl.UInt32).mod(n)

    def binarize(
        self, lit1: str, lit2: str, name: str = "binarized"
    ) -> pl.Expr:
        mod_expr = self._mod_expr(2)
        return (
            pl.when(mod_expr.eq(0))
            .then(pl.lit(lit1))
            .otherwise(pl.lit(lit2))
            .alias(name)
        )

    def trinarize(
        self, lit1: str, lit2: str, lit3: str, name: str = "trinarized"
    ) -> pl.Expr:
        mod_expr = self._mod_expr(3)
        return (
            pl.when(mod_expr.eq(0))
            .then(pl.lit(lit1))
            .when(mod_expr.eq(1))
            .then(pl.lit(lit2))
            .otherwise(pl.lit(lit3))
            .alias(name)
        )

    def bucketize(
        self, lits: list[Any], name: str = "bucketized"
    ) -> pl.Expr:
        mod_expr = self._mod_expr(len(lits))

        # first
        expr = pl.when(mod_expr.eq(0)).then(pl.lit(lits[0]))

        # middles
        for i, one_lit in enumerate(lits[1:-1], start=1):
            expr = expr.when(mod_expr.eq(i)).then(pl.lit(one_lit))

        # last
        expr = expr.otherwise(pl.lit(lits[-1]))
        return expr.alias(name)


df = (
    pl.DataFrame({"n": [100, 50, 72, 83, 97, 42, 20, 51, 77]})
    .with_row_index(offset=1)
    .with_columns(
        pl.col("").spt.binarize("lightblue", "papayawhip"),
        pl.col("").spt.trinarize("one", "two", "three"),
        pl.col("").spt.bucketize([1, 2, 3, 4]),
    )
)

print(df)
# Out:
# shape: (9, 5)
# ┌───────┬─────┬────────────┬────────────┬────────────┐
# │ index ┆ n   ┆ binarized  ┆ trinarized ┆ bucketized │
# │ ---   ┆ --- ┆ ---        ┆ ---        ┆ ---        │
# │ u32   ┆ i64 ┆ str        ┆ str        ┆ i32        │
# ╞═══════╪═════╪════════════╪════════════╪════════════╡
# │ 1     ┆ 100 ┆ lightblue  ┆ one        ┆ 1          │
# │ 2     ┆ 50  ┆ papayawhip ┆ two        ┆ 2          │
# │ 3     ┆ 72  ┆ lightblue  ┆ three      ┆ 3          │
# │ 4     ┆ 83  ┆ papayawhip ┆ one        ┆ 4          │
# │ 5     ┆ 97  ┆ lightblue  ┆ two        ┆ 1          │
# │ 6     ┆ 42  ┆ papayawhip ┆ three      ┆ 2          │
# │ 7     ┆ 20  ┆ lightblue  ┆ one        ┆ 3          │
# │ 8     ┆ 51  ┆ papayawhip ┆ two        ┆ 4          │
# │ 9     ┆ 77  ┆ lightblue  ┆ three      ┆ 1          │
# └───────┴─────┴────────────┴────────────┴────────────┘

# %%
(
    GT(df)
    .tab_style(style=style.fill(pl.col("binarized")), locations=loc.body())
    .opt_stylize(style=6)
)
# Out:
# GT(_tbl_data=shape: (9, 5)
# ┌───────┬─────┬────────────┬────────────┬────────────┐
# │ index ┆ n   ┆ binarized  ┆ trinarized ┆ bucketized │
# │ ---   ┆ --- ┆ ---        ┆ ---        ┆ ---        │
# │ u32   ┆ i64 ┆ str        ┆ str        ┆ i32        │
# ╞═══════╪═════╪════════════╪════════════╪════════════╡
# │ 1     ┆ 100 ┆ lightblue  ┆ one        ┆ 1          │
# │ 2     ┆ 50  ┆ papayawhip ┆ two        ┆ 2          │
# │ 3     ┆ 72  ┆ lightblue  ┆ three      ┆ 3          │
# │ 4     ┆ 83  ┆ papayawhip ┆ one        ┆ 4          │
# │ 5     ┆ 97  ┆ lightblue  ┆ two        ┆ 1          │
# │ 6     ┆ 42  ┆ papayawhip ┆ three      ┆ 2          │
# │ 7     ┆ 20  ┆ lightblue  ┆ one        ┆ 3          │
# │ 8     ┆ 51  ┆ papayawhip ┆ two        ┆ 4          │
# │ 9     ┆ 77  ┆ lightblue  ┆ three      ┆ 1          │
# └───────┴─────┴────────────┴────────────┴────────────┘, _body=<great_tables._gt_data.Body object at 0x000002A6B5681FD0>, _boxhead=Boxhead([ColInfo(var='index', type=<ColInfoTypeEnum.default: 1>, column_label='index', column_align='right', column_width=None), ColInfo(var='n', type=<ColInfoTypeEnum.default: 1>, column_label='n', column_align='right', column_width=None), ColInfo(var='binarized', type=<ColInfoTypeEnum.default: 1>, column_label='binarized', column_align='left', column_width=None), ColInfo(var='trinarized', type=<ColInfoTypeEnum.default: 1>, column_label='trinarized', column_align='left', column_width=None), ColInfo(var='bucketized', type=<ColInfoTypeEnum.default: 1>, column_label='bucketized', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000002A6B5681E80>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='index', rownum=0, colnum=None, styles=[CellStyleFill(color='lightblue')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='index', rownum=1, colnum=None, styles=[CellStyleFill(color='papayawhip')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='index', rownum=2, colnum=None, styles=[CellStyleFill(color='lightblue')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='index', rownum=3, colnum=None, styles=[CellStyleFill(color='papayawhip')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='index', rownum=4, colnum=None, styles=[CellStyleFill(color='lightblue')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='index', rownum=5, colnum=None, styles=[CellStyleFill(color='papayawhip')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='index', rownum=6, colnum=None, styles=[CellStyleFill(color='lightblue')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='index', rownum=7, colnum=None, styles=[CellStyleFill(color='papayawhip')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='index', rownum=8, colnum=None, styles=[CellStyleFill(color='lightblue')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='n', rownum=0, colnum=None, styles=[CellStyleFill(color='lightblue')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='n', rownum=1, colnum=None, styles=[CellStyleFill(color='papayawhip')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='n', rownum=2, colnum=None, styles=[CellStyleFill(color='lightblue')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='n', rownum=3, colnum=None, styles=[CellStyleFill(color='papayawhip')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='n', rownum=4, colnum=None, styles=[CellStyleFill(color='lightblue')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='n', rownum=5, colnum=None, styles=[CellStyleFill(color='papayawhip')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='n', rownum=6, colnum=None, styles=[CellStyleFill(color='lightblue')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='n', rownum=7, colnum=None, styles=[CellStyleFill(color='papayawhip')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='n', rownum=8, colnum=None, styles=[CellStyleFill(color='lightblue')]), StyleInfo(locname=LocBody(columns=None, rows=None, mask=None), grpname=None, colname='binarized', rownum=0, colnum=None, styles=[CellStyleFill(color='lightblue')]) ...
